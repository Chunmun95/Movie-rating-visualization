# %%
import pandas as pd
import os

# %%
movie = pd.read_csv('C:\\Users\\Acer\\Desktop\\P4-Movie-Ratings.csv')

# %%
len(movie)
# Out:
# 559

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.columns = ['Film', 'Genre', 'CriticalRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movie.head()
# Out:
#                     Film      Genre  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.describe()
# Out:
#        CriticalRating  AudienceRating  BudgetMillions         Year
# count      559.000000      559.000000      559.000000   559.000000
# mean        47.309481       58.744186       50.236136  2009.152057
# std         26.413091       16.826887       48.731817     1.362632
# min          0.000000        0.000000        0.000000  2007.000000
# 25%         25.000000       47.000000       20.000000  2008.000000
# 50%         46.000000       58.000000       35.000000  2009.000000
# 75%         70.000000       72.000000       65.000000  2010.000000
# max         97.000000       96.000000      300.000000  2011.000000

# %%
movie.Film = movie.Film.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movie.Genre = movie.Genre.astype('category')
movie.Year = movie.Year.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movie.describe()
# Out:
#        CriticalRating  AudienceRating  BudgetMillions
# count      559.000000      559.000000      559.000000
# mean        47.309481       58.744186       50.236136
# std         26.413091       16.826887       48.731817
# min          0.000000        0.000000        0.000000
# 25%         25.000000       47.000000       20.000000
# 50%         46.000000       58.000000       35.000000
# 75%         70.000000       72.000000       65.000000
# max         97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#joint plot

# %%
j = sns.jointplot(data=movie, x='CriticalRating', y='AudienceRating')

# %%
j = sns.jointplot(data=movie, x='CriticalRating', y='AudienceRating', kind='hex')

# %%
#histogram

# %%
m1 = sns.displot(movie.AudienceRating, bins=15)

# %%
m2 = sns.displot(movie.CriticalRating, bins=15)

# %%
n1 = plt.hist(movie.AudienceRating, bins=15)

# %%
sns.set_style('darkgrid')
n2 = plt.hist(movie.CriticalRating, bins=15)

# %%
# stacked histogram chart

# %%
#h1 = plt.hist(movie.BudgetMillions)
movie[movie.Genre == 'Drama'].BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
h1 = plt.hist(movie[movie.Genre == 'Drama'].BudgetMillions)

# %%
plt.hist(movie[movie.Genre == 'Action'].BudgetMillions, bins=15)
plt.hist(movie[movie.Genre == 'Drama'].BudgetMillions, bins=15)
plt.hist(movie[movie.Genre == 'Thriller'].BudgetMillions, bins=15)
plt.show()

# %%
plt.hist([movie[movie.Genre == 'Action'].BudgetMillions, movie[movie.Genre == 'Drama'].BudgetMillions], bins=15, stacked=True)
plt.show()

# %%
movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
list1 = list()
mylabels = list()
for gen in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre == gen].BudgetMillions)
    mylabels.append(gen)
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: BudgetMillions, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: BudgetMillions, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64, 7      32
# 12     35
# ...

# %%
h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()
plt.show()

# %%
#KDE plot

# %%
vis1 = sns.lmplot(data=movie, x='CriticalRating', y='AudienceRating', fit_reg=False, hue='Genre',
                 size=6, aspect=1)

# %%
k1 = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, shade=True, shade_lowest=False, cmap='Reds')

# %%
k1 = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, shade=True, shade_lowest=False, cmap='Reds')
k1b = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, cmap='Reds')

# %%
# working with subplot

# %%
sns.set_style("dark")
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating)

# %%
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating)

# %%
f, axes = plt.subplots(1,2, figsize=(12,6), sharex=True, sharey=True)
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating, ax=axes[0])
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating, ax=axes[1])
k2.set(xlim=(-50,250))
# Out:
# [(-50.0, 250.0)]

# %%
f, axes = plt.subplots(2,2, figsize=(12,6))
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating, ax=axes[0,0])
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating, ax=axes[1,1])

# %%
#violinplots

# %%
#z = sns.violinplot(data=movie, x='Genre', y="CriticalRating")
z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y="CriticalRating")

# %%
#z = sns.boxplot(data=movie, x='Genre', y="CriticalRating")
z = sns.boxplot(data=movie[movie.Genre=='Drama'], x='Year', y="CriticalRating")

# %%
#creating a facet grid

# %%
g = sns.FacetGrid(movie, row='Genre', col='Year',hue='Genre')

# %%
g = sns.FacetGrid(movie, row='Genre', col='Year',hue='Genre')
g = g.map(plt.scatter, 'CriticalRating', 'AudienceRating')

# %%
#can populate with any type of chart
g = sns.FacetGrid(movie, row='Genre', col='Year',hue='Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
#back to scatterplot
g = sns.FacetGrid(movie, row='Genre', col='Year',hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticalRating', 'AudienceRating', **kws)

# %%
#controlling axes and adding diagonals
g = sns.FacetGrid(movie, row='Genre', col='Year',hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticalRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c='gray', ls='--')
g.add_legend()

# %%
#building dashboard

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2, 2, figsize=(15,15))
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating, ax=axes[0,0])
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating, ax=axes[0,1])
z = sns.violinplot(data=movie, x='Year', y="BudgetMillions", ax=axes[1,0])
k1 = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
k1b = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, cmap='Reds', ax=axes[1,1])
k2.set(xlim=(-50,250))
k2b.set(xlim=(-50,250))
plt.show()

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2, 2, figsize=(15,15))
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating, ax=axes[0,0])
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating, ax=axes[0,1])
z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y="CriticalRating", ax=axes[1,0])
#k1 = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
#k1b = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, cmap='Reds', ax=axes[1,1])
axes[1,1].hist(movie.CriticalRating, bins=15)
k2.set(xlim=(-50,250))
k2b.set(xlim=(-50,250))
plt.show()

# %%
# styling dashboard

# %%
sns.set_style("dark", {"axes.facecolor": "black"})
f, axes = plt.subplots(2, 2, figsize=(15,15))
#plot1
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating,
                 shade=True, shade_lowest=True, cmap='inferno', ax=axes[0,0])
k2a = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating,
                 cmap='cool', ax=axes[0,0])
#plot2
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating,
                 shade=True, shade_lowest=True, cmap='inferno', ax=axes[0,1])
k2c = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating,
                 cmap='cool', ax=axes[0,1])
#plot3
z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y="CriticalRating", ax=axes[1,0])
#plot4
k1 = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, shade=True, shade_lowest=False, cmap='Blues_r', ax=axes[1,1])
k1b = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, cmap='gist_gray_r', ax=axes[1,1])
k2.set(xlim=(-50,250))
k2b.set(xlim=(-50,250))
plt.show()

# %%
sns.set_style("dark", {"axes.facecolor": "black"})
f, axes = plt.subplots(2, 2, figsize=(15,15))
#plot1
k2 = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating,
                 shade=True, shade_lowest=True, cmap='inferno', ax=axes[0,0])
k2a = sns.kdeplot(movie.BudgetMillions, movie.AudienceRating,
                 cmap='cool', ax=axes[0,0])
#plot2
k2b = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating,
                 shade=True, shade_lowest=True, cmap='inferno', ax=axes[0,1])
k2c = sns.kdeplot(movie.BudgetMillions, movie.CriticalRating,
                 cmap='cool', ax=axes[0,1])
#plot3
z = sns.violinplot(data=movie, x='Year', y="BudgetMillions", ax=axes[1,0],
                  palette='YlOrRd')
#plot4
k1 = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, shade=True, shade_lowest=False, cmap='Blues_r', ax=axes[1,1])
k1b = sns.kdeplot(movie.CriticalRating, movie.AudienceRating, cmap='gist_gray_r', ax=axes[1,1])
k2.set(xlim=(-50,250))
k2b.set(xlim=(-50,250))
plt.show()

# %%
# thematic edits

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.title("Movie Burget Distribution", fontsize=35, color="DarkBlue", fontname="Console")
plt.ylabel("Number of Movies", fontsize=25, color="Red")
plt.xlabel("budget", fontsize=25, color="Green")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True, fancybox=True, shadow=True, framealpha=1, prop={'size':20})
plt.show()
